# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('death_by_risk_factor.csv', index_col = 0)

# %%
dataset_br = dataset.loc['Brazil']

# %%
dataset_br
# Out:
#        Code  Year  \
# Entity
# Brazil  BRA  1990
# Brazil  BRA  1991
# Brazil  BRA  1992
# Brazil  BRA  1993
# Brazil  BRA  1994
# Brazil  BRA  1995
# Brazil  BRA  1996
# Brazil  BRA  1997
# Brazil  BRA  1998
# Brazil  BRA  1999
# Brazil  BRA  2000
# Brazil  BRA  2001
# Brazil  BRA  2002
# Brazil  BRA  2003
# Brazil  BRA  2004
# Brazil  BRA  2005
# Brazil  BRA  2006
# Brazil  BRA  2007
# Brazil  BRA  2008
# Brazil  BRA  2009
# Brazil  BRA  2010
# Brazil  BRA  2011
# Brazil  BRA  2012
# Brazil  BRA  2013
# Brazil  BRA  2014
# Brazil  BRA  2015
# Brazil  BRA  2016
# Brazil  BRA  2017
#
#         Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)  \
# Entity
# Brazil                                       31596.672865
# Brazil                                       29208.336019
# Brazil                                       26729.132040
# Brazil                                       24492.815316
# Brazil                                       22152.178802
# ...

# %%
dataset_br[['Deaths - Air pollution - Sex: Both - Age: All Ages (Number)']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, Brazil to Brazil
# Data columns (total 1 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Deaths - Air pollution - Sex: Both - Age: All Ages (Number)  28 non-null     float64
# dtypes: float64(1)
# memory usage: 448.0+ bytes

# %%
dataset_br_air_pollution = dataset_br[['Year','Deaths – Outdoor air pollution (all ages) (IHME)']]

# %%
dataset_br_air_pollution
# Out:
#         Year  Deaths – Outdoor air pollution (all ages) (IHME)
# Entity
# Brazil  1990                                          27331.81
# Brazil  1991                                          27680.94
# Brazil  1992                                          29015.14
# Brazil  1993                                          30939.15
# Brazil  1994                                          32018.00
# Brazil  1995                                          32831.69
# Brazil  1996                                          33861.04
# Brazil  1997                                          34577.35
# Brazil  1998                                          35855.83
# Brazil  1999                                          36854.92
# Brazil  2000                                          37154.53
# Brazil  2001                                          38036.63
# Brazil  2002                                          39002.43
# Brazil  2003                                          40214.65
# ...

# %%
grafico = dataset_br_air_pollution.plot.line(x = 'Year', y = 'Deaths – Outdoor air pollution (all ages) (IHME)', title = "Progressão de mortes por poluiçao do ar no Brasil", xlabel = "Ano", ylabel = "Numero de mortes", legend = False, fontsize= 14, figsize =(10,8))
figure = grafico.get_figure()
figure.get_figure()

# %%
figure.savefig('Mortes por Poluicao do Ar no Brasil 1990 - 2015')
